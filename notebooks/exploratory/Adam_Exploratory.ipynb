# %%
import sqlite3
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd

# %%
master_df = pd.read_csv("proj2data/master.csv")
# Out:
# /Users/adamroth/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (105,111) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
master_df.sample(10)
# Out:
#                id  ExciseTaxNbr DocumentDate  SalePrice    RecordingNbr  \
# 36937  5151600110       2971414   01/23/2019     415000  20190125000818
# 18970  2436700705       2977835   03/15/2019          0  20190318000385
# 5409    821069080       3011947   09/25/2019    4829830  20190925000838
# 11407  1522059184       3015528   10/10/2019     560000  20191016000220
# 32039  3903800040       2977610   03/12/2019    1850000  20190315000405
# 9270   1313000510       2981204   03/29/2019     740000
# 17575  2254501610       2983632   03/30/2019          0  20190423000031
# 59952  9365700030       3007672   08/23/2019    1050000  20190829001049
# 32777  4024100305       3016227   10/11/2019          0  20191018001759
# 16813  2156400364       2986062   04/30/2019      65000  20190503001100
#
#       Volume Page PlatNbr PlatType         PlatLot  ... FpFreestanding  \
# 36937                                               ...            0.0
# ...

# %%
master_df.columns
# Out:
# Index(['id', 'ExciseTaxNbr', 'DocumentDate', 'SalePrice', 'RecordingNbr',
#        'Volume', 'Page', 'PlatNbr', 'PlatType', 'PlatLot',
#        ...
#        'FpFreestanding', 'FpAdditional', 'YrBuilt', 'YrRenovated',
#        'PcntComplete', 'Obsolescence', 'PcntNetCondition', 'Condition',
#        'AddnlCost', 'footprint'],
#       dtype='object', length=151)

# %%
columns_list = []
for i in range(len(master_df.columns)):
    columns_list.append(master_df.columns[i])
               
columns_list
# Out:
# ['id',
#  'ExciseTaxNbr',
#  'DocumentDate',
#  'SalePrice',
#  'RecordingNbr',
#  'Volume',
#  'Page',
#  'PlatNbr',
#  'PlatType',
#  'PlatLot',
#  'PlatBlock',
#  'SellerName',
#  'BuyerName',
#  'PropertyType',
#  'PrincipalUse',
#  'SaleInstrument',
#  'AFForestLand',
#  'AFCurrentUseLand',
#  'AFNonProfitUse',
#  'AFHistoricProperty',
#  'SaleReason',
#  'PropertyClass',
#  'SaleWarning',
#  'PropName',
#  'PlatName',
#  'PlatLotparcel',
#  'PlatBlockparcel',
#  'Range',
#  'Township',
#  'Section',
#  'QuarterSection',
#  'PropType',
#  'Area',
#  'SubArea',
#  'SpecArea',
#  'SpecSubArea',
#  'DistrictName',
#  'LevyCode',
#  'CurrentZoning',
#  'HBUAsIfVacant',
#  'HBUAsImproved',
#  'PresentUse',
#  'SqFtLot',
#  'WaterSystem',
#  'SewerSystem',
#  'Access',
#  'Topography',
#  'StreetSurface',
#  'RestrictiveSzShape',
#  'InadequateParking',
#  'PcntUnusable',
#  'Unbuildable',
#  'MtRainier',
#  'Olympics',
#  'Cascades',
#  'Territorial',
#  'SeattleSkyline',
# ...

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62039 entries, 0 to 62038
# Columns: 151 entries, id to footprint
# dtypes: float64(82), int64(8), object(61)
# memory usage: 71.5+ MB

# %%
sales_df = pd.read_csv("proj2data/EXTR_RPSale.csv")
# Out:
# /Users/adamroth/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sales_df.head()
# Out:
#    ExciseTaxNbr   Major Minor DocumentDate  SalePrice    RecordingNbr Volume  \
# 0       2687551  138860   110   08/21/2014     245000  20140828001436
# 1       1235111  664885    40   07/09/1991          0  199203161090      071
# 2       2704079  423943    50   10/11/2014          0  20141205000558
# 3       2584094  403700   715   01/04/2013          0  20130110000910
# 4       3027422  213043   120   12/20/2019     560000  20191226000848
#
#   Page PlatNbr PlatType  ... PropertyType PrincipalUse SaleInstrument  \
# 0                        ...            3            6              3
# 1  001  664885        C  ...            3            0             26
# 2                        ...            3            6             15
# 3                        ...            3            6             15
# 4                        ...           11            6              3
#
#   AFForestLand  AFCurrentUseLand  AFNonProfitUse  AFHistoricProperty  \
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089099 entries, 0 to 2089098
# Data columns (total 24 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ExciseTaxNbr        int64
#  1   Major               object
#  2   Minor               object
#  3   DocumentDate        object
#  4   SalePrice           int64
#  5   RecordingNbr        object
#  6   Volume              object
#  7   Page                object
#  8   PlatNbr             object
#  9   PlatType            object
#  10  PlatLot             object
#  11  PlatBlock           object
#  12  SellerName          object
#  13  BuyerName           object
#  14  PropertyType        int64
#  15  PrincipalUse        int64
#  16  SaleInstrument      int64
#  17  AFForestLand        object
#  18  AFCurrentUseLand    object
#  19  AFNonProfitUse      object
#  20  AFHistoricProperty  object
#  21  SaleReason          int64
#  22  PropertyClass       int64
#  23  SaleWarning         object
# ...

# %%
res_df = pd.read_csv("proj2data/EXTR_ResBldg.csv")
# Out:
# /Users/adamroth/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
res_df.head()
# Out:
#    Major  Minor  BldgNbr  NbrLivingUnits                    Address  \
# 0  46100    935        1               1  7349   10TH AVE NW  98117
# 1  46100   1165        1               1  7342   11TH AVE NW  98117
# 2  46100   1720        1               1  7330   13TH AVE NW  98117
# 3  46100   1745        1               1  7348   13TH AVE NW  98117
# 4  46100   1930        1               1  7306   14TH AVE NW  98117
#
#   BuildingNumber Fraction DirectionPrefix                 StreetName  \
# 0          7349                            10TH
# 1          7342                            11TH
# 2          7330                            13TH
# 3          7348                            13TH
# 4          7306                            14TH
#
#   StreetType  ... FpMultiStory FpFreestanding  FpAdditional  YrBuilt  \
# 0     AVE     ...            0              0             0     1927
# 1     AVE     ...            0              0             0     2019
# ...

# %%
parcel_df = pd.read_csv("proj2data/EXTR_Parcel.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 5: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-e5b620ff87b9> in <module>
# ----> 1 parcel_df = pd.read_csv("proj2data/EXTR_Parcel.csv")
#
# ...

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62039 entries, 0 to 62038
# Columns: 151 entries, id to footprint
# dtypes: float64(82), int64(8), object(61)
# memory usage: 71.5+ MB

# %%
df = master_df[master_df.PropertyType.isin([11,12,13,14])]
print(len(master_df))
print(len(df))
# Out:
# 62039
# 31228
